# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# which can able to tough with hand are called hardware
# ex:mouse, keyboard,monitor etc.
# which can not able to tough with hand and those can able to use to by coding with textual order is called software.
# ex: ms office, c,c++ programme etc
